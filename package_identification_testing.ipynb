# %%
from PIL import Image
Image.open('test_images/test.jpg').resize((384, 384))
# Out:
# <PIL.Image.Image image mode=RGB size=384x384>

# %% [markdown]
# ### Palitan mo lang IP address below to your IP
#
# *baka iba din yung port instead of 8000*, pero probably 8000 as well

# %%
import requests, json

url = "http://192.168.254.118:8000/upload-image/"
files = {"file": open("test_images/test2.jpg", "rb")}

response = requests.post(url, files=files)
response.json()
# Out:
# '{"matches": [{"INDEX": "6319", "Registration Number": "DRP-8154", "Generic Name": "Levothyroxine Sodium", "Brand Name": "Euthyrox 50", "Dosage Strength": "50 mcg", "Dosage Form": "Tablet", "Classification": "Prescription Drug (RX)", "Packaging": "Alu-Alu Blister Pack x 25s (Box of 100\'s)", "Pharmacologic Category": "Thyroid Hormone Replacement", "Manufacturer": "Merck S.A. DE C.V.", "Country of Origin": "Mexico", "Trader": NaN, "Importer": "Merck, Inc.", "Distributor": NaN, "Application Type": "Renewal", "Issuance Date": "23-Jun-24", "Expiry Date": "14-Aug-29", "match_score": 79.1, "rx_info": {"Name": "Levothyroxine Sodium (Levoxyl)", "URL": "https://www.rxlist.com/levoxyl-drug.htm", "What is": "\\nLevoxyl (levothyroxine sodium) Tablets is a replacement for a hormone that is normally produced by your thyroid gland used to treat hypothyroidism (low thyroid hormone). Levoxyl is also used to treat or prevent goiter (enlarged thyroid gland), which can be caused by hormone imbalances, radiation treatment, surgery, or cancer. Levoxyl is available in generic form.", "What Are Side Effects": "\\nCommon side effects of Levoxyl include hair loss during the first few months of treatment. This effect is usually temporary as your body adjusts to Levoxyl. Contact your doctor if you have serious side effects of Levoxyl including:\\r\\n\\nheadache, \\nsleep problems (insomnia), \\nnervousness,\\nirritability,\\nfever, \\nhot flashes, \\nsweating, \\npounding heartbeats or fluttering in your chest, \\nchanges in your menstrual periods, or \\nappetite or weight changes.\\n\\nDosage for Levoxyl\\nDosage of Levoxyl is individualized. Levoxyl may interact with lithium, amiodarone, antidepressants, or radiation therapy with iodine.\\nWhat Drugs, Substances, or Supplements Interact with Levoxyl?\\nMany other drugs can interact with Levoxyl. Tell your doctor all prescription and over-the-counter medications you use. There are other drugs that can be taken while taking Levoxyl, but they must be taken 4 hours before, or 4 hours after taking Levoxyl. Consult your doctor.\\nLevoxyl During Pregnancy and Breastfeeding\\nCurrent information shows Levoxyl may be used during pregnancy. Tell your doctor if you are pregnant because your dose may need to be adjusted. This medication passes into breast milk but is unlikely to harm a nursing infant. Consult your doctor before breast-feeding. \\nAdditional Information\\nOur Levoxyl (levothyroxine sodium) Side Effects Drug Center provides a comprehensive view of available drug information on the potential side effects when taking this medication.\\r\\n", "Children": "No info", "Dosage": "No info", "Interact": "No info", "Pregnancy": "No info"}}, {"INDEX": "6318", "Registration Number": "DRP-8153", "Generic Name": "Levothyroxine Sodium", "Brand Name": "Euthyrox 100", "Dosage Strength": "100 mcg", "Dosage Form": "Tablet", "Classification": "Prescription Drug (RX)", "Packaging": "Alu-Alu Blister x 25s (Box of 100\'s)", "Pharmacologic Category": "Thyroid Hormone Replacement", "Manufacturer": "Merck S.A. de C.V.", "Country of Origin": "Mexico", "Trader": NaN, "Importer": "Merck, Inc.", "Distributor": NaN, "Application Type": "Renewal", "Issuance Date": "10-Jul-24", "Expiry Date": "14-Aug-29", "match_score": 78.7, "rx_info": {"Name": "Levothyroxine Sodium (Levoxyl)", "URL": "https://www.rxlist.com/levoxyl-drug.htm", "What is": "\\nLevoxyl (levothyroxine sodium) Tablets is a replacement for a hormone that is normally produced by your thyroid gland used to treat hypothyroidism (low thyroid hormone). Levoxyl is also used to treat or prevent goiter (enlarged thyroid gland), which can be caused by hormone imbalances, radiation treatment, surgery, or cancer. Levoxyl is available in generic form.", "What Are Side Effects": "\\nCommon side effects of Levoxyl include hair loss during the first few months of treatment. This effect is usually temporary as your body adjusts to Levoxyl. Contact your doctor if you have serious side e ...

# %%
import requests, json

url = "https://fastapi-app-613987678533.asia-southeast1.run.app/upload-image/"
files = {"file": open("test_images/test3.jpg", "rb")}

response = requests.post(url, files=files)
response.json()
# Out:
# '{"matches": [{"INDEX": "9809", "Registration Number": "DRP-10064", "Generic Name": "Candesartan Cilexetil", "Brand Name": "Candez", "Dosage Strength": "8 mg", "Dosage Form": "Tablet", "Classification": "Prescription Drug (RX)", "Packaging": "Alu/PVC Blister Pack x 10s (box of 30s)", "Pharmacologic Category": "Angiotensin II Receptor Blocker (ARB)", "Manufacturer": "Amherst Laboratories, Inc.", "Country of Origin": "Philippines", "Trader": "UNILAB, Inc.", "Importer": NaN, "Distributor": NaN, "Application Type": "Renewal", "Issuance Date": "8-Jan-24", "Expiry Date": "11-May-29", "match_score": 68.8, "rx_info": {"Name": "Atacand (Candesartan Cilexetil)", "URL": "https://www.rxlist.com/atacand-drug.htm", "What is": "\\nAtacand (candesartan cilexetil) is a selective AT1 subtype angiotensin II receptor antagonist used to treat high blood pressure (hypertension) in adults and children 1 to less than 17 years of age.", "What Are Side Effects": "\\nAtacand\\u00a0may cause serious side effects including:\\n\\nlightheadedness,\\nfast or slow heartbeats,\\nunusual muscle pain or weakness,\\nnausea,\\nweakness,\\ntingly feeling,\\nchest pain,\\nirregular heartbeats,\\nloss of movements,\\nlittle or no urination,\\nswelling in your feet or ankles,\\nfeeling tired, and\\nshortness of breath\\n\\nGet medical help right away, if you have any of the symptoms listed above.\\nCommon side effects of Atacand include:\\n\\nrunny or stuffy nose, \\nsore throat, \\ncough, \\nback pain, \\njoint pain, \\nstomach pain, \\ndiarrhea, \\nheadache, \\ndizziness, \\ntired feeling, \\nfeeling like you might pass out, \\nchest pain, \\nswelling in your hands or feet, \\nslow heart rate, \\nweak pulse, or \\ntingly feeling. \\n\\nTell the doctor immediately if you notice any of these side effects. \\nSeek medical care or call 911 at once if you have the following serious side effects:\\n\\nSerious eye symptoms such as sudden vision loss, blurred vision, tunnel vision, eye pain or swelling, or seeing halos around lights;\\nSerious heart symptoms such as fast, irregular, or pounding heartbeats; fluttering in your chest; shortness of breath; and sudden dizziness, lightheadedness, or passing out;\\nSevere headache, confusion, slurred speech, arm or leg weakness, trouble walking, loss of coordination, feeling unsteady, very stiff muscles, high fever, profuse sweating, or tremors.\\n\\nThis document does not contain all possible side effects and others may occur. Check with your physician for additional information about side effects.", "Children": "No info", "Dosage": "\\nThe usual recommended starting dose of Atacand is 16 mg once daily when it is used as monotherapy in patients who are not volume depleted. Atacand can be administered once or twice daily with total daily doses ranging from 8 mg to 32 mg.", "Interact": "\\nAtacand may interact with alcohol, potassium supplements or salt substitutes, diuretics (water pills), lithium; or NSAIDs (non-steroidal anti-inflammatory drugs)\\r\\nTell your doctor all medications and supplements you use. ", "Pregnancy": "No info"}}, {"INDEX": "7310", "Registration Number": "DRP-4609-02", "Generic Name": "Candesartan Cilexetil", "Brand Name": NaN, "Dosage Strength": "8 mg", "Dosage Form": "Tablet", "Classification": "Prescription Drug (RX)", "Packaging": "Alu/Alu Blister Pack x 7\'s (Box of 28\'s)", "Pharmacologic Category": "Angiotensin-2-Receptor Blocker", "Manufacturer": "XL Laboratories Pvt. Ltd.", "Country of Origin": "India", "Trader": NaN, "Importer": "Ambica International Trading Corp.", "Distributor": "Actimed, Inc.", "Application Type": "Automatic Renewal", "Issuance Date": "16-Jan-23", "Expiry Date": "8-Aug-28", "match_score": 68.0, "rx_info": {"Name": "Atacand (Candesartan Cilexetil)", "URL": "https://www.rxlist.com/atacand-drug.htm", "What is": "\\nAtacand (candesartan cilexetil) is a selective AT1 subtype angiotensin II receptor antagonist used to treat high blood pressure (hypertension) in adults and children 1  ...

# %%
json.loads(response.json())
# Out:
# {'matches': [{'INDEX': '9809',
#    'Registration Number': 'DRP-10064',
#    'Generic Name': 'Candesartan Cilexetil',
#    'Brand Name': 'Candez',
#    'Dosage Strength': '8 mg',
#    'Dosage Form': 'Tablet',
#    'Classification': 'Prescription Drug (RX)',
#    'Packaging': 'Alu/PVC Blister Pack x 10s (box of 30s)',
#    'Pharmacologic Category': 'Angiotensin II Receptor Blocker (ARB)',
#    'Manufacturer': 'Amherst Laboratories, Inc.',
#    'Country of Origin': 'Philippines',
#    'Trader': 'UNILAB, Inc.',
#    'Importer': nan,
#    'Distributor': nan,
#    'Application Type': 'Renewal',
#    'Issuance Date': '8-Jan-24',
#    'Expiry Date': '11-May-29',
#    'match_score': 68.8,
#    'rx_info': {'Name': 'Atacand (Candesartan Cilexetil)',
#     'URL': 'https://www.rxlist.com/atacand-drug.htm',
#     'What is': '\nAtacand (candesartan cilexetil) is a selective AT1 subtype angiotensin II receptor antagonist used to treat high blood pressure (hypertension) in adults and children 1 to less than 17 years of age.',
#     'What Are Side Effects': '\nAtacand\xa0may cause serious side effects including:\n\nlightheadedness,\nfast or slow heartbeats,\nunusual muscle pain or weakness,\nnausea,\nweakness,\ntingly feeling,\nchest pain,\nirregular heartbeats,\nloss of movements,\nlittle or no urination,\nswelling in your feet or ankles,\nfeeling tired, and\nshortness of breath\n\nGet medical help right away, if you have any of the symptoms listed above.\nCommon side effects of Atacand include:\n\nrunny or stuffy nose, \nsore throat, \ncough, \nback pain, \njoint pain, \nstomach pain, \ndiarrhea, \nheadache, \ndizziness, \ntired feeling, \nfeeling like you might pass out, \nchest pain, \nswelling in your hands or feet, \nslow heart rate, \nweak pulse, or \ntingly feeling. \n\nTell the doctor immediately if you notice any of these side effects. \nSeek medical care or call 911 at once if you have the following serious side effects:\n\nSerious eye symptoms such as sudden vision loss, blurred vision, tunnel vision, eye pain or swelling, or seeing halos around lights;\nSerious heart symptoms such as fast, irregular, or pounding heartbeats; fluttering in your chest; shortness of breath; and sudden dizziness, lightheadedness, or passing out;\nSevere headache, confusion, slurred speech, arm or leg weakness, trouble walking, loss of coordination, feeling unsteady, very stiff muscles, high fever, profuse sweating, or tremors.\n\nThis document does not contain all possible side effects and others may occur. Check with your physician for additional information about side effects.',
#     'Children': 'No info',
#     'Dosage': '\nThe usual recommended starting dose of Atacand is 16 mg once daily when it is used as monotherapy in patients who are not volume depleted. Atacand can be administered once or twice daily with total daily doses ranging from 8 mg to 32 mg.',
#     'Interact': '\nAtacand may interact with alcohol, potassium supplements or salt substitutes, diuretics (water pills), lithium; or NSAIDs (non-steroidal anti-inflammatory drugs)\r\nTell your doctor all medications and supplements you use. ',
#     'Pregnancy': 'No info'}},
#   {'INDEX': '7310',
#    'Registration Number': 'DRP-4609-02',
#    'Generic Name': 'Candesartan Cilexetil',
#    'Brand Name': nan,
#    'Dosage Strength': '8 mg',
#    'Dosage Form': 'Tablet',
#    'Classification': 'Prescription Drug (RX)',
#    'Packaging': "Alu/Alu Blister Pack x 7's (Box of 28's)",
#    'Pharmacologic Category': 'Angiotensin-2-Receptor Blocker',
#    'Manufacturer': 'XL Laboratories Pvt. Ltd.',
#    'Country of Origin': 'India',
#    'Trader': nan,
#    'Importer': 'Ambica International Trading Corp.',
#    'Distributor': 'Actimed, Inc.',
#    'Application Type': 'Automatic Renewal',
#    'Issuance Date': '16-Jan-23',
#    'Expiry Date': '8-Aug-28',
#    'match_score': 68.0,
#    'rx_info': {'Name': 'Atacand (Candesartan Cilexetil)',
#     'URL': 'https://www.rxlist.com/atacand-drug.htm',
#     'What is': '\nAtacand (candesartan cilexetil) is a selective AT1 subtype angiotensin II receptor antagonist used to treat high blood pressure (hypertension) in adults and children 1 to less than 17 years of age.',
#     'What Are Side Effects': '\nAtacand\xa0may cause serious side effects including:\n\nlightheadedness,\nfast or slow heartbeats,\nunusual muscle pain or weakness,\nnausea,\nweakness,\ntingly feeling,\nchest pain,\nirregular heartbeats,\nloss of movements,\nlittle or no urination,\nswelling in your feet or ankles,\nfeeling tired, and\nshortness of breath\n\nGet medical help right away, if you have any of the symptoms listed above.\nCommon side effects of Atacand include:\n\nrunny or stuffy nose, \nsore throat, \ncough, \nback pain, \njoint pain, \nstomach pain, \ndiarrhea, \nheadache, \ndizziness, \ntired feeling, \nfeeling like you might pass out, \nchest pain, \nswelling in your hands or feet, \nslow heart rate, \nweak pulse, or \ntingly feeling. \n\nTell the doctor immediately if you notice any of these side effects. \nSeek medical care or call 911 at once if you have the following serious side effects:\n\nSerious eye symptoms such as sudden vision loss, blurred vision, tunnel vision, eye pain or swelling, or seeing halos around lights;\nSerious heart symptoms such as fast, irregular, or pounding heartbeats; fluttering in your chest; shortness of breath; and sudden dizziness, lightheadedness, or passing out;\nSevere headache, confusion, slurred speech, arm or leg weakness, trouble walking, loss of coordination, feeling unsteady, very stiff muscles, high fever, profuse sweating, or tremors.\n\nThis document does not contain all possible side effects and others may occur. Check with your physician for additional information about side effects.',
#     'Children': 'No info',
#     'Dosage': '\nThe usual recommended starting dose of Atacand is 16 mg once daily when it is used as monotherapy in patients who are not volume depleted. Atacand can be administered once or twice daily with total daily doses ranging from 8 mg to 32 mg.',
#     'Interact': '\nAtacand may interact with alcohol, potassium supplements or salt substitutes, diuretics (water pills), lithium; or NSAIDs (non-steroidal anti-inflammatory drugs)\r\nTell your doctor all medications and supplements you use. ',
#     'Pregnancy': 'No info'}},
#   {'INDEX': '7309',
#    'Registration Number': 'DRP-4609-01',
#    'Generic Name': 'Candesartan Cilexetil',
#    'Brand Name': 'Desaren',
#    'Dosage Strength': '8 mg',
#    'Dosage Form': 'Tablet',
#    'Classification': 'Prescription Drug (RX)',
#    'Packaging': "Alu/Alu Blister Pack x 7's (Box of 28's)",
#    'Pharmacologic Category': 'Angiotensin-2-Receptor Blocker',
#    'Manufacturer': 'XL Laboratories Pvt. Ltd.',
#    'Country of Origin': 'India',
#    'Trader': nan,
#    'Importer': 'Ambica International Trading Corp.',
#    'Distributor': 'Medilyn Drug',
#    'Application Type': 'Automatic Renewal',
#    'Issuance Date': '16-Apr-23',
#    'Expiry Date': '8-Aug-28',
#    'match_score': 63.3,
#    'rx_info': {'Name': 'Atacand (Candesartan Cilexetil)',
#     'URL': 'https://www.rxlist.com/atacand-drug.htm',
#     'What is': '\nAtacand (candesartan cilexetil) is a selective AT1 subtype angiotensin II receptor antagonist used to treat high blood pressure (hypertension) in adults and children 1 to less than 17 years of age.',
#     'What Are Side Effects': '\nAtacand\xa0may cause serious side effects including:\n\nlightheadedness,\nfast or slow heartbeats,\nunusual muscle pain or weakness,\nnausea,\nweakness,\ntingly feeling,\nchest pain,\nirregular heartbeats,\nloss of movements,\nlittle or no urination,\nswelling in your feet or ankles,\nfeeling tired, and\nshortness of breath\n\nGet medical help right away, if you have any of the symptoms listed above.\nCommon side effects of Atacand include:\n\nrunny or stuffy nose, \nsore throat, \ncough, \nback pain, \njoint pain, \nstomach pain, \ndiarrhea, \nheadache, \ndizziness, \ntired feeling, \nfeeling like you might pass out, \nchest pain, \nswelling in your hands or feet, \nslow heart rate, \nweak pulse, or \ntingly feeling. \n\nTell the doctor immediately if you notice any of these side effects. \nSeek medical care or call 911 at once if you have the following serious side effects:\n\nSerious eye symptoms such as sudden vision loss, blurred vision, tunnel vision, eye pain or swelling, or seeing halos around lights;\nSerious heart symptoms such as fast, irregular, or pounding heartbeats; fluttering in your chest; shortness of breath; and sudden dizziness, lightheadedness, or passing out;\nSevere headache, confusion, slurred speech, arm or leg weakness, trouble walking, loss of coordination, feeling unsteady, very stiff muscles, high fever, profuse sweating, or tremors.\n\nThis document does not contain all possible side effects and others may occur. Check with your physician for additional information about side effects.',
#     'Children': 'No info',
#     'Dosage': '\nThe usual recommended starting dose of Atacand is 16 mg once daily when it is used as monotherapy in patients who are not volume depleted. Atacand can be administered once or twice daily with total daily doses ranging from 8 mg to 32 mg.',
#     'Interact': '\nAtacand may interact with alcohol, potassium supplements or salt substitutes, diuretics (water pills), lithium; or NSAIDs (non-steroidal anti-inflammatory drugs)\r\nTell your doctor all medications and supplements you use. ',
#     'Pregnancy': 'No info'}}]}

# %%
# gcloud config set project master-deck-448603-j0

# docker build -t asia-southeast1-docker.pkg.dev/master-deck-448603-j0/fastapi-repo/fastapi-app .
# docker push asia-southeast1-docker.pkg.dev/master-deck-448603-j0/fastapi-repo/fastapi-app

# gcloud run deploy fastapi-app --image asia-southeast1-docker.pkg.dev/master-deck-448603-j0/fastapi-repo/fastapi-app --platform managed --region asia-southeast1 --allow-unauthenticated
# Out:
#   Cell In[6], line 1
#     docker build -t asia-southeast1-docker.pkg.dev/master-deck-448603-j0/fastapi-repo/fastapi-app .
#            ^
# SyntaxError: invalid syntax
