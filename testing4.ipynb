# %%
import pandas as pd
import random
import json

fda_df = pd.read_csv('FDA_pills.csv')

fake_addresses = [
    "36th Floor, The Finance Center, 26th Street, BGC, Taguig", 
    "No. 66 United Street, Mandaluyong City, Metro Manila", 
    "UNILAB Pharma Campus, Barangay Mamplasan, Biñan Laguna, Philippines",
    "Unit 12A, Ayala Triangle Gardens Tower 2, Makati City",
    "15th Floor, Net Park Building, 5th Avenue, Bonifacio Global City",
    "789 Sampaloc Avenue, Manila",
    "22 Acacia Street, Quezon City",
    "Lot 10, Industrial Park, Calamba, Laguna",
    "Building 5, TechnoHub, UP Diliman, Quezon City",
    "456 Rizal Avenue Extension, Pasay City",
    "901 Ortigas Center, Pasig City",
    "123 Barangay Poblacion, San Juan",
    "Suite 8B, Rockwell Center, Makati",
    "Km. 25, South Superhighway, Muntinlupa",
    "Warehouse 7, Laguna Technopark, Santa Rosa",
    "111 Congressional Avenue, Quezon City",
    "202 Shaw Boulevard, Mandaluyong",
    "333 Alabang-Zapote Road, Las Piñas",
    "444 C5 Road, Taguig",
    "555 EDSA, Cubao, Quezon City",
    "666 Visayas Avenue, Quezon City",
    "777 Mindanao Avenue, Quezon City",
    "888 Aurora Boulevard, Quezon City",
    "999 España Boulevard, Manila",
    "1010 Taft Avenue, Manila",
    "1212 Roxas Boulevard, Manila",
    "1313 Makati Avenue, Makati City",
    "1414 Ayala Avenue, Makati City",
    "1515 Paseo de Roxas, Makati City",
    "1616 BGC High Street, Taguig",
    "1717 Eastwood City, Quezon City",
    "1818 Araneta Center, Quezon City",
    "1919 Greenbelt, Makati City"
]

# Sample warning texts
warnings = [
    "Do not accept if seal is broken",
    "Not recommended for pregnant women",
    "Keep out of reach of children",
    "Store in a cool, dry place away from sunlight"
]

new_warnings = [
    "consult your doctor before use.",
    "for external use only.",
    "discontinue use if irritation occurs.",
    "avoid contact with eyes.",
    "may cause drowsiness.",
    "do not use with other medications.",
    "keep away from direct sunlight.",
    "use only as directed.",
    "do not exceed recommended dosage.",
    "seek medical advice if symptoms persist.",
    "not for children under 12 years.",
    "may interact with alcohol.",
    "store at room temperature.",
    "shake well before using.",
    "do not freeze.",
    "may cause allergic reactions.",
    "read the label carefully.",
    "for professional use only.",
    "may impair ability to drive or operate machinery.",
    "do not use if pregnant or breastfeeding.",
    "report any side effects to your doctor.",
    "may cause skin sensitivity.",
    "do not crush or chew.",
    "swallow whole.",
    "may cause gastrointestinal upset.",
    "use with caution in elderly patients.",
    "may cause changes in blood pressure.",
    "do not use if you have a history of seizures.",
    "may increase risk of bleeding.",
    "may affect blood sugar levels."
]

warnings.extend([w.upper() if random.random() < 0.3 else w.lower() if random.random() < 0.3 else w.capitalize() for w in new_warnings])

# %%
# Define templates for synthetic OCR-like text
TEMPLATES = [
    "{warning} {generic} {brand} {dosage} {form} {classification} R Manufactured by {manufacturer}, {address}. {packaging} {importer}",
    "{generic} {brand} {dosage} {form} {classification} Manufactured by {manufacturer} at {address}. {packaging}. Imported by {importer}.",
    "{generic} {dosage} {form} {classification} {packaging}. Distributed by {distributor}, {address}.",
    "{warning} {generic} {brand} {dosage} {form} {packaging}. Distributor: {distributor}, {address}. Manufacturer: {manufacturer}.",
    "{brand}  {generic} {dosage} {form}. {classification}. {packaging}. {warning} Imported by {importer} at {address}."
]

# Generate synthetic NER data
TRAIN_DATA = []

for _, row in fda_df.iterrows():
    # Select random address and warning
    address = random.choice(fake_addresses)
    warning = random.choice(warnings)
    
    # Fill template with medication details
    sentence = random.choice(TEMPLATES).format(
        generic=row["Generic Name"],
        brand=row["Brand Name"],
        dosage=row["Dosage Strength"],
        form=row["Dosage Form"],
        classification=row["Classification"],
        packaging=row["Packaging"],
        manufacturer=row["Manufacturer"],
        importer=row["Importer"],
        distributor=row["Distributor"],
        address=address,
        warning=warning
    )
    
    

    # Convert all values to strings and replace NaNs with empty strings
    row = row.fillna("").astype(str)
    # Track used spans to prevent overlapping entities
    used_spans = set()

    # Define entity spans
    entities = []
    for col, label in zip(
        ["Generic Name", "Brand Name", "Dosage Strength", "Dosage Form", "Classification", "Packaging", "Manufacturer", "Importer", "Distributor"],
        ["GENERIC_NAME", "BRAND_NAME", "DOSAGE_STRENGTH", "DOSAGE_FORM", "CLASSIFICATION", "PACKAGING", "MANUFACTURER", "IMPORTER", "DISTRIBUTOR"]
    ):
        value = row[col]
        if value:  # Ensure the value is not empty
            start = sentence.find(value)
            end = start + len(value)
            
            # Check if the span overlaps with any existing ones
            if start != -1 and not any(s <= start < e or s < end <= e for s, e, _ in entities):
                entities.append((start, end, label))
                used_spans.add((start, end))  # Track this span

        
    # Append to training data
    TRAIN_DATA.append((sentence, {"entities": entities}))

# Save the dataset
with open("synthetic_ner_ocr.json", "w") as f:
    json.dump(TRAIN_DATA, f, indent=4)

# Print sample output
for sample in TRAIN_DATA[:5]:
    print(sample)
# Out:
# ("Lactobacillus gasseri + Lactobacillus rhamnosus Ecovag Formulation: Each hard vaginal capsule contains: Lactobacillus gasseri EB01 strain........Min. 10^8 cfu Lactobacillus rhamnosus PB01 strain..........Min. 10^8 cfu Hard Vaginal Capsule Prescription Drug (RX) Manufactured by Deerland Priobiotics &amp; Enzymes A/S at 333 Alabang-Zapote Road, Las Piñas. Aluminum tube with polyethylene desiccant stopper x 10's (Box of 1's and 4's). Imported by Zeus Resources, Inc..", {'entities': [(0, 47, 'GENERIC_NAME'), (48, 54, 'BRAND_NAME'), (55, 217, 'DOSAGE_STRENGTH'), (218, 238, 'DOSAGE_FORM'), (239, 261, 'CLASSIFICATION'), (356, 433, 'PACKAGING'), (278, 316, 'MANUFACTURER'), (447, 467, 'IMPORTER')]})
# ("Not recommended for pregnant women Affinity-Purified Antibodies To Human Interferon Gamma Anaferon 3 mg Orodispersible Tablet Alu/PVC blister pack x 20's (Box of 20's). Distributor: Metro Drug, Inc., 666 Visayas Avenue, Quezon City. Manufacturer: “NPF” Materia Medica Holding.", {'entities': [(35, 89, 'GENERIC_NAME'), (90, 98, 'BRAND_NAME'), (99, 103, 'DOSAGE_STRENGTH'), (104, 125, 'DOSAGE_FORM'), (126, 167, 'PACKAGING'), (247, 275, 'MANUFACTURER'), (182, 198, 'DISTRIBUTOR')]})
# ("OraVacs  Cholera Vaccine (inactivated, oral) Formulation Each capsule contains: Inactivated Whole Cell (WC)-5.0 x 10^10 of Vibrio cholerae 01 Inaba, classical biotype (heat inactivated)\r\nRecombinant cholera toxin B subunit (ICTB)--1 mg (produced in V. cholerae 01 Inaba, classical biotype or El Tor biotype) Enteric-Coated Capsule. Prescription Drug (RX). Aluminum blister foil (Box of 3's). Store in a cool, dry place away from sunlight Imported by ULIVaccines, Inc. at 15th Floor, Net Park Building, 5th Avenue, Bonifacio Global City.", {'entities': [(9, 44, 'GENERIC_NAME'), (0, 7, 'BRAND_NAME'), (45, 307, 'DOSAGE_STRENGTH'), (308, 330, 'DOSAGE_FORM'), (332, 354, 'CLASSIFICATION'), (356, 390, 'PACKAGING'), (450, 467, 'IMPORTER')]})
# ("Keep out of reach of children Furosemide Lasix 40 mg Tablet Prescription Drug (RX) R Manufactured by Handok Inc., 36th Floor, The Finance Center, 26th Street, BGC, Taguig. Green transparent PVC/Alu Blister Pack x 15's Sanofi Aventis Philippines, Inc.", {'entities': [(30, 40, 'GENERIC_NAME'), (41, 46, 'BRAND_NAME'), (47, 52, 'DOSAGE_STRENGTH'), (53, 59, 'DOSAGE_FORM'), (60, 82, 'CLASSIFICATION'), (172, 217, 'PACKAGING'), (101, 112, 'MANUFACTURER'), (218, 250, 'IMPORTER')]})
# ("FUCIDIN  Sodium Fusidate 250 mg Film-Coated Tablet. Prescription Drug (RX). Blister Pack x 10's (Box of 20's). Swallow whole. Imported by Zuellig Pharma Corporation at Warehouse 7, Laguna Technopark, Santa Rosa.", {'entities': [(9, 24, 'GENERIC_NAME'), (0, 7, 'BRAND_NAME'), (25, 31, 'DOSAGE_STRENGTH'), (32, 50, 'DOSAGE_FORM'), (52, 74, 'CLASSIFICATION'), (76, 109, 'PACKAGING'), (138, 164, 'IMPORTER')]})

# %%
import spacy
from spacy.training.example import Example
import json

# Load synthetic data
with open("synthetic_ner_ocr.json", "r") as f:
    TRAIN_DATA = json.load(f)

# Load a blank model
nlp = spacy.blank("en")
ner = nlp.add_pipe("ner")

# Add entity labels
for _, annotations in TRAIN_DATA:
    for ent in annotations["entities"]:
        ner.add_label(ent[2])

# Training loop
optimizer = nlp.begin_training()

for epoch in range(10):
    for text, annotations in TRAIN_DATA:
        example = Example.from_dict(nlp.make_doc(text), annotations)
        nlp.update([example], drop=0.2)

# Save trained model
nlp.to_disk("medication_ner")
# Out:
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Lactobacillus gasseri + Lactobacillus rhamnosus Ec..." with entities "[[0, 47, 'GENERIC_NAME'], [48, 54, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Avoid contact with eyes. Thiamine mononitrate (Vit..." with entities "[[25, 129, 'GENERIC_NAME'], [130, 144, 'BRAND_NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not accept if seal is broken Warfarin Sodium (A..." with entities "[[32, 62, 'GENERIC_NAME'], [63, 71, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Phenobarbital 30 mg Tablet Prescription Drug (RX) ..." with entities "[[0, 13, 'GENERIC_NAME'], [14, 19, 'DOSAGE_STRENGT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "not for children under 12 years. Vitamin B Complex..." with entities "[[33, 62, 'GENERIC_NAME'], [63, 72, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not use with other medications. Phenylpropanola..." with entities "[[35, 107, 'GENERIC_NAME'], [108, 117, 'BRAND_NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not use if you have a history of seizures. Dexa..." with entities "[[46, 59, 'GENERIC_NAME'], [60, 68, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not accept if seal is broken Dexamethasone Dren..." with entities "[[32, 45, 'GENERIC_NAME'], [46, 52, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Amoxicillin (as trihydrate) Amoxil 250 mg Capsule ..." with entities "[[0, 27, 'GENERIC_NAME'], [28, 34, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not use if you have a history of seizures. Levo..." with entities "[[46, 66, 'GENERIC_NAME'], [67, 75, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Use with caution in elderly patients. Phenobarbita..." with entities "[[38, 51, 'GENERIC_NAME'], [56, 61, 'DOSAGE_STRENG...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "not for children under 12 years. Aluminum Hydroxid..." with entities "[[33, 95, 'GENERIC_NAME'], [96, 104, 'BRAND_NAME']...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not use if pregnant or breastfeeding. Phenobarb..." with entities "[[41, 54, 'GENERIC_NAME'], [55, 64, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "not for children under 12 years. Multivitamis + Ir..." with entities "[[33, 52, 'GENERIC_NAME'], [53, 64, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May cause changes in blood pressure. Allopurinol P..." with entities "[[37, 48, 'GENERIC_NAME'], [49, 57, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "store at room temperature. Amoxicillin (As Trihydr..." with entities "[[27, 54, 'GENERIC_NAME'], [55, 60, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Multivitamins + Iron + Calcium Sangobion Forte 360..." with entities "[[0, 30, 'GENERIC_NAME'], [31, 46, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Warfarin Sodium (As Clathrate) Coumadin 1mg Tablet..." with entities "[[0, 30, 'GENERIC_NAME'], [31, 39, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May impair ability to drive or operate machinery. ..." with entities "[[50, 68, 'GENERIC_NAME'], [69, 77, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not crush or chew. Terbinafine (As Hydrochlorid..." with entities "[[22, 52, 'GENERIC_NAME'], [53, 60, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Swallow whole. Flucloxacillin (As Sodium) Stafloxi..." with entities "[[15, 41, 'GENERIC_NAME'], [42, 51, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "may cause drowsiness. Paroxetine Seroxat 20mg Tabl..." with entities "[[22, 32, 'GENERIC_NAME'], [33, 40, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Store in a cool, dry place away from sunlight Acyc..." with entities "[[46, 55, 'GENERIC_NAME'], [56, 63, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not use with other medications. Mefenamic Acid ..." with entities "[[35, 49, 'GENERIC_NAME'], [50, 58, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MAY INTERACT WITH ALCOHOL. Thiamine Mononitrate (V..." with entities "[[27, 122, 'GENERIC_NAME'], [123, 131, 'BRAND_NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May cause gastrointestinal upset. Naproxen Naprosy..." with entities "[[34, 42, 'GENERIC_NAME'], [43, 55, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Alprazolam Xanor 1 mg Tablet Prescription Drug (RX..." with entities "[[0, 10, 'GENERIC_NAME'], [11, 16, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Consult your doctor before use. Lacidipine Lacipil..." with entities "[[32, 42, 'GENERIC_NAME'], [43, 50, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May impair ability to drive or operate machinery. ..." with entities "[[50, 60, 'GENERIC_NAME'], [61, 71, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "store at room temperature. Amoxicillin (As Trihydr..." with entities "[[27, 54, 'GENERIC_NAME'], [55, 61, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SEEK MEDICAL ADVICE IF SYMPTOMS PERSIST. Amoxicill..." with entities "[[41, 68, 'GENERIC_NAME'], [69, 75, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Lamotrigine Lamictal 100mg Tablet Prescription Dru..." with entities "[[0, 11, 'GENERIC_NAME'], [12, 20, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May impair ability to drive or operate machinery. ..." with entities "[[50, 76, 'GENERIC_NAME'], [77, 84, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MAY AFFECT BLOOD SUGAR LEVELS. Cefalexin (As Monoh..." with entities "[[31, 57, 'GENERIC_NAME'], [58, 65, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "For external use only. Amoxicillin (as trihydrate)..." with entities "[[23, 50, 'GENERIC_NAME'], [51, 58, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "FOR PROFESSIONAL USE ONLY. Chloramphenicol C-Pheni..." with entities "[[27, 42, 'GENERIC_NAME'], [43, 53, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Avoid contact with eyes. Paracetamol Anaseran 500m..." with entities "[[25, 36, 'GENERIC_NAME'], [37, 45, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Cefuroxime (As Axetil) Zinnat 250 mg Tablet Prescr..." with entities "[[0, 22, 'GENERIC_NAME'], [23, 29, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Cefuroxime (as axetil) Zinnat 500 mg Tablet Over-T..." with entities "[[0, 22, 'GENERIC_NAME'], [23, 29, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May cause gastrointestinal upset. Amoxicillin (As ..." with entities "[[34, 61, 'GENERIC_NAME'], [62, 68, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Use only as directed. Cotrimoxazole Triphimox 400 ..." with entities "[[22, 35, 'GENERIC_NAME'], [36, 45, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "FERROUS SULFATE nan 200mg Capsule Over-The-Counter..." with entities "[[0, 15, 'GENERIC_NAME'], [20, 25, 'DOSAGE_STRENGT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May increase risk of bleeding. Ciclosporin Sandimm..." with entities "[[31, 42, 'GENERIC_NAME'], [43, 59, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Piracetam Nootropil 1.2g Film-Coated Tablet Prescr..." with entities "[[0, 9, 'GENERIC_NAME'], [10, 19, 'BRAND_NAME'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Acyclovir Zovirax 200 mg Tablet Prescription Drug ..." with entities "[[0, 9, 'GENERIC_NAME'], [10, 17, 'BRAND_NAME'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Vitagen  Thiamine Mononitrate + Pyridoxine Hydroch..." with entities "[[9, 73, 'GENERIC_NAME'], [0, 7, 'BRAND_NAME'], [7...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not use if you have a history of seizures. Thia..." with entities "[[46, 141, 'GENERIC_NAME'], [142, 154, 'BRAND_NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May impair ability to drive or operate machinery. ..." with entities "[[50, 81, 'GENERIC_NAME'], [82, 89, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Paracetamol nan 500mg Tablet Over-The-Counter (OTC..." with entities "[[0, 11, 'GENERIC_NAME'], [16, 21, 'DOSAGE_STRENGT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Report any side effects to your doctor. Furosemide..." with entities "[[40, 50, 'GENERIC_NAME'], [51, 56, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May cause gastrointestinal upset. Lamotrigine Lami..." with entities "[[34, 45, 'GENERIC_NAME'], [46, 54, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May increase risk of bleeding. Salbutamol (As Sulf..." with entities "[[31, 54, 'GENERIC_NAME'], [55, 61, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mefenamic Acid 500 mg Capsule Prescription Drug (R..." with entities "[[0, 14, 'GENERIC_NAME'], [15, 21, 'DOSAGE_STRENGT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May increase risk of bleeding. Cefalexin (as Monoh..." with entities "[[31, 57, 'GENERIC_NAME'], [58, 65, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Indapamide Natrilix SR 1.5 mg Sustained-Release Ta..." with entities "[[0, 10, 'GENERIC_NAME'], [11, 22, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mycophenolate Mofetil Cellcept 500 mg Tablet Presc..." with entities "[[0, 21, 'GENERIC_NAME'], [22, 30, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Not recommended for pregnant women Phenobarbital n..." with entities "[[35, 48, 'GENERIC_NAME'], [53, 58, 'DOSAGE_STRENG...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May impair ability to drive or operate machinery. ..." with entities "[[50, 63, 'GENERIC_NAME'], [64, 79, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Shake well before using. Harvimide Loperamide (as ..." with entities "[[25, 34, 'GENERIC_NAME'], [35, 64, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Use with caution in elderly patients. Olanzapine Z..." with entities "[[38, 48, 'GENERIC_NAME'], [49, 56, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Use with caution in elderly patients. Multivitamin..." with entities "[[38, 65, 'GENERIC_NAME'], [66, 73, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Keep away from direct sunlight. Acetylcysteine Flu..." with entities "[[32, 46, 'GENERIC_NAME'], [47, 56, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Not recommended for pregnant women Bambuterol Hydr..." with entities "[[35, 59, 'GENERIC_NAME'], [60, 67, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MAY AFFECT BLOOD SUGAR LEVELS. Pinene (Alpha + Bet..." with entities "[[31, 148, 'GENERIC_NAME'], [149, 158, 'BRAND_NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Imidapril Hydrochloride Norten 5mg Tablet Prescrip..." with entities "[[0, 23, 'GENERIC_NAME'], [24, 30, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Store in a cool, dry place away from sunlight Levo..." with entities "[[46, 75, 'GENERIC_NAME'], [76, 81, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Use only as directed. Imidapril Hydrochloride Vasc..." with entities "[[22, 45, 'GENERIC_NAME'], [46, 52, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Paracetamol + Ibuprofen 325 mg/200 mg Tablet Over-..." with entities "[[0, 23, 'GENERIC_NAME'], [24, 37, 'DOSAGE_STRENGT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Consult your doctor before use. Montelukast (as So..." with entities "[[32, 55, 'GENERIC_NAME'], [56, 65, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "discontinue use if irritation occurs. Mefenamic Ac..." with entities "[[38, 52, 'GENERIC_NAME'], [53, 60, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May impair ability to drive or operate machinery. ..." with entities "[[50, 114, 'GENERIC_NAME'], [115, 124, 'BRAND_NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SEEK MEDICAL ADVICE IF SYMPTOMS PERSIST. Metronida..." with entities "[[41, 54, 'GENERIC_NAME'], [55, 61, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pentoxifylline Trental 400 mg Film - Coated Tablet..." with entities "[[0, 14, 'GENERIC_NAME'], [15, 22, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Rabeprazole Sodium Pariet 20mg Tablet Prescription..." with entities "[[0, 18, 'GENERIC_NAME'], [19, 25, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Rabeprazole Sodium Pariet 10mg Tablet Prescription..." with entities "[[0, 18, 'GENERIC_NAME'], [19, 25, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tamoxifen  (As Citrate) Gyraxen 20 mg Film-Coated ..." with entities "[[0, 23, 'GENERIC_NAME'], [24, 31, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not freeze. Cefaclor (as monohydrate) Xelent 50..." with entities "[[15, 40, 'GENERIC_NAME'], [41, 47, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SEEK MEDICAL ADVICE IF SYMPTOMS PERSIST. Multivita..." with entities "[[41, 54, 'GENERIC_NAME'], [55, 62, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Aciclovir Herpex 400 mg Tablet Prescription Drug (..." with entities "[[0, 9, 'GENERIC_NAME'], [10, 16, 'BRAND_NAME'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "not for children under 12 years. Aciclovir Herpex ..." with entities "[[33, 42, 'GENERIC_NAME'], [43, 49, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Avoid contact with eyes. Multivitamins with Lysine..." with entities "[[25, 64, 'GENERIC_NAME'], [65, 73, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Prednisolone Prednecort 5 mg Tablet Prescription D..." with entities "[[0, 12, 'GENERIC_NAME'], [13, 23, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Carvedilol Dilatrend 6.25 mg Tablet Prescription D..." with entities "[[0, 10, 'GENERIC_NAME'], [11, 20, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "For external use only. Bisoprolol Fumarate + Hydro..." with entities "[[23, 64, 'GENERIC_NAME'], [65, 69, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SEEK MEDICAL ADVICE IF SYMPTOMS PERSIST. Cefalexin..." with entities "[[41, 67, 'GENERIC_NAME'], [72, 78, 'DOSAGE_STRENG...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mesalazine Pentasa 500 mg Prolonged-Release Tablet..." with entities "[[0, 10, 'GENERIC_NAME'], [11, 18, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Keep away from direct sunlight. Multivitamins + Mi..." with entities "[[32, 56, 'GENERIC_NAME'], [57, 64, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Use only as directed. Multivitamins+Mineral Termin..." with entities "[[22, 43, 'GENERIC_NAME'], [44, 52, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "not for children under 12 years. Phentermine Durom..." with entities "[[33, 44, 'GENERIC_NAME'], [45, 56, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not crush or chew. Guaifenesin + Salbutamol Sal..." with entities "[[22, 46, 'GENERIC_NAME'], [47, 56, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Esomeprazole (As Magnesium Trihydrate) Nexium® 20 ..." with entities "[[0, 38, 'GENERIC_NAME'], [39, 46, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May cause allergic reactions. Pentoxifylline Pento..." with entities "[[30, 44, 'GENERIC_NAME'], [45, 55, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Report any side effects to your doctor. Lincomycin..." with entities "[[40, 64, 'GENERIC_NAME'], [65, 71, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not accept if seal is broken Naproxen Sodium Sk..." with entities "[[32, 47, 'GENERIC_NAME'], [48, 58, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Bisoprolol Fumarate + Hydrochlorothiazide Ziac 5mg..." with entities "[[0, 41, 'GENERIC_NAME'], [42, 46, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "not for children under 12 years. Metoprolol Tartra..." with entities "[[33, 52, 'GENERIC_NAME'], [53, 60, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Neurolink Forte  Thiamine Mononitrate + Pyridoxine..." with entities "[[17, 81, 'GENERIC_NAME'], [0, 15, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "may cause drowsiness. Fluconazole Flucoral 150 mg ..." with entities "[[22, 33, 'GENERIC_NAME'], [34, 42, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Cefaclor (As Monohydrate) nan 500 MG Capsule Presc..." with entities "[[0, 25, 'GENERIC_NAME'], [30, 36, 'DOSAGE_STRENGT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Cefuroxime (as Axetil) C-Tri-T 500 mg Film-Coated ..." with entities "[[0, 22, 'GENERIC_NAME'], [23, 30, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May cause allergic reactions. Salbutamol Sulfate +..." with entities "[[30, 62, 'GENERIC_NAME'], [63, 78, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ivabradine (as hydrochloride) Coralan 5mg Film-Coa..." with entities "[[0, 29, 'GENERIC_NAME'], [30, 37, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "INDAPAMIDE VAZAMIDE SR 1.5mg Sustained-Release Tab..." with entities "[[0, 10, 'GENERIC_NAME'], [11, 22, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "may cause drowsiness. Glimepiride Acotril 4 mg Tab..." with entities "[[22, 33, 'GENERIC_NAME'], [34, 41, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Paracetamol + Thiamine Mononitrate (Vitamin B1) + ..." with entities "[[0, 118, 'GENERIC_NAME'], [119, 133, 'BRAND_NAME'...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May cause gastrointestinal upset. Levofloxacin Flo..." with entities "[[34, 46, 'GENERIC_NAME'], [47, 53, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not use if pregnant or breastfeeding. Clopidogr..." with entities "[[41, 67, 'GENERIC_NAME'], [68, 75, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May increase risk of bleeding. Paracetamol + Diphe..." with entities "[[31, 60, 'GENERIC_NAME'], [61, 68, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Anagrelide (As Hydrochloride) Thromboreductin 500m..." with entities "[[0, 29, 'GENERIC_NAME'], [30, 45, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Report any side effects to your doctor. Deferasiro..." with entities "[[40, 51, 'GENERIC_NAME'], [52, 58, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "For external use only. Flucloxacillin (as Sodium) ..." with entities "[[23, 49, 'GENERIC_NAME'], [58, 63, 'DOSAGE_STRENG...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not exceed recommended dosage. Gabapentin Reini..." with entities "[[34, 44, 'GENERIC_NAME'], [45, 51, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Keep out of reach of children Montelukast (as Sodi..." with entities "[[30, 53, 'GENERIC_NAME'], [54, 62, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May cause gastrointestinal upset. Ketorolac Tromet..." with entities "[[34, 54, 'GENERIC_NAME'], [55, 62, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MAY INTERACT WITH ALCOHOL. Fenofibrate Inofib 300 ..." with entities "[[27, 38, 'GENERIC_NAME'], [39, 45, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Fenofibrate 300 mg Capsule Prescription Drug (RX) ..." with entities "[[0, 11, 'GENERIC_NAME'], [12, 18, 'DOSAGE_STRENGT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Montelukast (as sodium) Montiget 5mg Chewable Tabl..." with entities "[[0, 23, 'GENERIC_NAME'], [24, 32, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Simvastatin Simvoget 40mg Film-Coated Tablet Presc..." with entities "[[0, 11, 'GENERIC_NAME'], [12, 20, 'BRAND_NAME'], ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Consult your doctor before use. Losartan Potassium..." with entities "[[32, 50, 'GENERIC_NAME'], [51, 57, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Store in a cool, dry place away from sunlight Dicl..." with entities "[[46, 68, 'GENERIC_NAME'], [69, 75, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ciclosporin 25mg Softgel Capsule Prescription Drug..." with entities "[[0, 11, 'GENERIC_NAME'], [12, 16, 'DOSAGE_STRENGT...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Do not use with other medications. Gabapentin Calm..." with entities "[[35, 45, 'GENERIC_NAME'], [46, 54, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May cause allergic reactions. Gabapentin Calmpent ..." with entities "[[30, 40, 'GENERIC_NAME'], [41, 49, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "discontinue use if irritation occurs. Ferrous Sulf..." with entities "[[38, 179, 'GENERIC_NAME'], [180, 187, 'BRAND_NAME...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "May cause allergic reactions. Pioglitazone (as hyd..." with entities "[[30, 61, 'GENERIC_NAME'], [62, 67, 'BRAND_NAME'],...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 24
#      22     for text, annotations in TRAIN_DATA:
#      23         example = Example.from_dict(nlp.make_doc(text), annotations)
# ---> 24         nlp.update([example], drop=0.2)
#      26 # Save trained model
#      27 nlp.to_disk("medication_ner")
#
# File c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\language.py:1196, in Language.update(self, examples, _, drop, sgd, losses, component_cfg, exclude, annotates)
#    1193 for name, proc in self.pipeline:
#    1194     # ignore statements are used here because mypy ignores hasattr
#    1195     if name not in exclude and hasattr(proc, "update"):
# -> 1196         proc.update(examples, sgd=None, losses=losses, **component_cfg[name])  # type: ignore
#    1197     if sgd not in (None, False):
#    1198         if (
#    1199             name not in exclude
#    1200             and isinstance(proc, ty.TrainableComponent)
#    1201             and proc.is_trainable
#    1202             and proc.model not in (True, False, None)
#    1203         ):
#
# File c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\pipeline\transition_parser.pyx:431, in spacy.pipeline.transition_parser.Parser.update()
#
# File c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\spacy\ml\parser_model.pyx:360, in spacy.ml.parser_model.step_forward.backprop_parser_step()
#
# File c:\Users\Jandrik\Documents\MyFILES\Programming\Python Files\Programs\vino\Lib\site-packages\thinc\layers\linear.py:44, in forward.<locals>.backprop(dY)
#      42 model.inc_grad("b", dY.sum(axis=0))
#      43 model.inc_grad("W", model.ops.gemm(dY, X, trans1=True))
# ---> 44 return model.ops.gemm(dY, W)
#
# KeyboardInterrupt:

# %%
# Test the model
nlp = spacy.load("medication_ner")
doc = nlp("Levothyroxine sodium 50 mcg Tablet is manufactured by Merck Inc. and is available in 100 Tablets packaging.")

for ent in doc.ents:
    print(ent.text, ent.label_)
